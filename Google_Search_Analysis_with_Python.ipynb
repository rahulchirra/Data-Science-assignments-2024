# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulchirra/Data-Science-assignments-2024/blob/main/Google_Search_Analysis_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %%
trends.build_payload(kw_list=['pornhub'])
data = trends.interest_by_region()
data = data.sort_values(by=['pornhub'], ascending=False)
data.head(10)
print(data)
# Out:
#                       pornhub
# geoName
# Philippines               100
# Trinidad & Tobago          65
# Serbia                     58
# Bosnia & Herzegovina       57
# Sri Lanka                  49
# ...                       ...
# Honduras                    0
# Iceland                     0
# Isle of Man                 0
# Jamaica                     0
# Åland Islands               0
#
# [250 rows x 1 columns]

# %%
print(data.head(10))
# Out:
#                       pornhub
# geoName
# Philippines               100
# Trinidad & Tobago          65
# Serbia                     58
# Bosnia & Herzegovina       57
# Sri Lanka                  49
# Lebanon                    48
# Romania                    47
# Austria                    46
# Croatia                    46
# Ireland                    46

# %%
data.reset_index().plot(x='geoName',
                        y='pornhub',
                        kind='bar')
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['pornhub'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(15, 12))
data['pornhub'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for pornhub',
          fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()
